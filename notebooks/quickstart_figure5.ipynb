# %% [markdown]
# # Quickstart: Figure 5 motif-pair interactions
#
# This notebook invokes the release CLI to regenerate Figure 5 computational panels from frozen local inputs. It does not retrain models or rerun motif discovery.

# %%
# Install from the repository root before using this notebook:
# pip install -e '.[figures]'
# If the assets are not embedded at release_assets/, set this path to the downloaded archive.
import os
# os.environ['DROSOPHILA_REPRO_PACKAGE_ROOT'] = '/path/to/release_assets'

# %%
import subprocess, sys
subprocess.run(['drosophila-repro', 'doctor'], check=True)
subprocess.run(['drosophila-repro', 'reproduce', '--figure', 'figure5'], check=True)

# %% [markdown]
# The expected panels are the null-calibration, discovery summary, top-pair, complete-matrix, and distance/context exports. Compare their release hashes/visuals with the final Figure 5 composite according to `docs/ACCEPTANCE_PROTOCOL.md`.
